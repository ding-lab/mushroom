# %%
import json
from collections import Counter

import matplotlib.pyplot as plt
import numpy as np
import tifffile
import torch
import torch.nn as nn
import torchvision.transforms.functional as TF
from torch.utils.data import DataLoader, Dataset
from torchvision.transforms import RandomHorizontalFlip, RandomVerticalFlip, Normalize, RandomCrop, Compose

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import multiplex_imaging_pipeline.utils as utils
from vit_pytorch import ViT, MAE
from vit_pytorch.slide_mae import SlideMAE

# %%
metadata = json.load(open('../data/test_registration/HT397B1_v2/registered/metadata.json'))
metadata
# Out:
# {'downsample_scaler': 0.1,
#  'phenocycler_pixels_per_micron': 1.9604911906033102,
#  'order': ['HT397B1-S1H3A1U1',
#   'HT397B1-S1H3A1U2',
#   'HT397B1-S1H3A1U12',
#   'HT397B1-S1H3A1U21',
#   'HT397B1-S1H3A1U22',
#   'HT397B1-S1H3A1U31'],
#  'data_type': ['visium', 'codex', 'codex', 'visium', 'codex', 'codex'],
#  'slices': ['s0', 's1', 's2', 's3', 's4', 's5']}

# %%
fps = sorted(utils.listfiles('/data/estorrs/mushroom/data/test_registration/HT397B1_v2/registered',
                     regex='ome.tiff$'))
fps
# Out:
# ['/data/estorrs/mushroom/data/test_registration/HT397B1_v2/registered/s1.ome.tiff',
#  '/data/estorrs/mushroom/data/test_registration/HT397B1_v2/registered/s2.ome.tiff',
#  '/data/estorrs/mushroom/data/test_registration/HT397B1_v2/registered/s4.ome.tiff',
#  '/data/estorrs/mushroom/data/test_registration/HT397B1_v2/registered/s5.ome.tiff']

# %%
pool = []
for fp in fps:
    channels = utils.get_ome_tiff_channels(fp)
    channels = [utils.R_CHANNEL_MAPPING.get(c, c) for c in channels]
    pool += channels
Counter(pool).most_common()
# Out:
# /data/estorrs/miniconda3/envs/mushroom/lib/python3.10/site-packages/ome_types/_convenience.py:106: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# [('Bap1', 4),
#  ('CD31', 4),
#  ('CD45', 4),
#  ('CD68', 4),
#  ('CD8', 4),
#  ('CK19', 4),
#  ('COX6c', 4),
#  ('DAPI', 4),
#  ('ER', 4),
#  ('FOXP3', 4),
#  ('GATA3', 4),
#  ('GLUT1', 4),
#  ('HLA-DR', 4),
#  ('Her2', 4),
#  ('CK14', 4),
#  ('Ki67', 4),
#  ('MGP', 4),
#  ('PLAT/tPA', 4),
#  ('PR', 4),
#  ('Pan-Cytokeratin', 4),
#  ('Podoplanin', 4),
#  ('SMA', 4),
#  ('Vimentin', 4),
#  ('cKit', 4),
#  ('CD20', 2),
#  ('CD3e', 2),
#  ('CD11b', 1),
#  ('E-cadherin', 1)]

# %%
channels = sorted([c for c, count in Counter(pool).items() if count==len(fps)])
channels
# Out:
# ['Bap1',
#  'CD31',
#  'CD45',
#  'CD68',
#  'CD8',
#  'CK14',
#  'CK19',
#  'COX6c',
#  'DAPI',
#  'ER',
#  'FOXP3',
#  'GATA3',
#  'GLUT1',
#  'HLA-DR',
#  'Her2',
#  'Ki67',
#  'MGP',
#  'PLAT/tPA',
#  'PR',
#  'Pan-Cytokeratin',
#  'Podoplanin',
#  'SMA',
#  'Vimentin',
#  'cKit']

# %%
channels = [
    'CD45',
    'CD8',
    'CK14',
    'MGP',
    'Pan-Cytokeratin',
    'SMA',
    'Vimentin',
]

# %%
scale = .1
slide_to_img = {}
for fp in fps:
    sample = fp.split('/')[-1].replace('.ome.tiff', '')
    cs, img = utils.extract_ome_tiff(fp, as_dict=False)
    img = torch.tensor(img)
    thumbnail = TF.resize(img, (int(scale * img.shape[-2]), int(scale * img.shape[-1])))
    thumbnail = thumbnail.to(torch.float32)
    
    cs = [utils.R_CHANNEL_MAPPING[c] for c in cs]
    idxs = [cs.index(c) for c in channels]
    thumbnail = thumbnail[idxs]
    
    slide_to_img[sample] = thumbnail

# %%
thumbnail = next(iter(slide_to_img.values()))

# %%
plt.imshow(thumbnail[channels.index('Pan-Cytokeratin')])

# %%
plt.imshow(thumbnail[channels.index('Pan-Cytokeratin'), 500:764, 500:764])

# %%
class MAETransform(object):
    def __init__(self, size=(256, 256), normalize=None):
        self.transforms = Compose([
            RandomCrop(size, padding_mode='reflect'),
            RandomHorizontalFlip(),
            RandomVerticalFlip(),
            normalize if normalize is not None else nn.Identity()
        ])

    def __call__(self, x):
        return self.transforms(x)


class SlideDataset(Dataset):
    def __init__(self, slide_to_img, transform=None):
        self.slides = sorted(slide_to_img.keys())
        self.slide_to_img = slide_to_img

        self.transform = transform if transform is not None else nn.Identity()

    def __len__(self):
        return np.iinfo(np.int64).max # make infinite

    def __getitem__(self, idx):
        slide = np.random.choice(self.slides)
        idx = self.slides.index(slide)
        return {
            'slide_idx': idx,
            'img': transform(self.slide_to_img[slide])
        }

# %%
means = torch.cat([x.mean(dim=(-2, -1)).unsqueeze(0) for x in slide_to_img.values()]).mean(0)
stds = torch.cat([x.std(dim=(-2, -1)).unsqueeze(0) for x in slide_to_img.values()]).mean(0)
means, stds
# Out:
# (tensor([ 1.9242,  0.4242,  1.5283,  4.9701, 19.0076,  4.8628, 21.0575]),
#  tensor([ 4.6411,  2.7208, 11.1956,  9.9388, 52.9554, 21.8240, 44.8913]))

# %%
size = (256, 256)

normalize = Normalize(means, stds)
transform = MAETransform(normalize=normalize)
ds = SlideDataset(slide_to_img, transform=transform)

# %%
d = ds[0]
tile = d['img']
slide_idx = d['slide_idx']
slide_idx
# Out:
# 1

# %%
plt.imshow(tile[channels.index('Pan-Cytokeratin')])

# %%
dl = DataLoader(ds, batch_size=64, num_workers=10)

# %%
v = ViT(
    image_size = size[0],
    patch_size = 32,
    num_classes = 1000,
    dim = 1024,
    depth = 6,
    heads = 8,
    mlp_dim = 2048,
    channels=len(channels),
)

# %%
mae = SlideMAE(
    encoder = v,
    n_slides = len(slide_to_img),
    masking_ratio = 0.25,   # the paper recommended 75% masked patches
    decoder_dim = 512,      # paper showed good results with just 512
    decoder_depth = 6       # anywhere from 1 to 8
)

# %%
v = v.cuda()
mae = mae.cuda()

# %%
iters = 100000
lr = 1e-4
opt = torch.optim.Adam(mae.parameters(), lr=lr)

# %%
# !mkdir -p ../data/mae_v2

# %%
for i, b in enumerate(dl):
    opt.zero_grad()
    
    slide_idxs, imgs = b['slide_idx'], b['img']
    slide_idxs, imgs = slide_idxs.cuda(), imgs.cuda()
    loss, _ = mae(imgs, slide_idxs)
    loss.backward()
    opt.step()
    
    if i % 100 == 0:
        print(i, loss)
        
    if i % 1000 == 0:
        torch.save(v.state_dict(), f'../data/mae_v2/{i}iter.pt')
        
    if i == iters:
        break
# Out:
# 0 tensor(1.8747, device='cuda:0', grad_fn=<MseLossBackward0>)
# 100 tensor(1.6075, device='cuda:0', grad_fn=<MseLossBackward0>)
# 200 tensor(1.2414, device='cuda:0', grad_fn=<MseLossBackward0>)
# 300 tensor(1.3025, device='cuda:0', grad_fn=<MseLossBackward0>)
# 400 tensor(1.0569, device='cuda:0', grad_fn=<MseLossBackward0>)
# 500 tensor(0.9703, device='cuda:0', grad_fn=<MseLossBackward0>)
# 600 tensor(1.0245, device='cuda:0', grad_fn=<MseLossBackward0>)
# 700 tensor(1.0333, device='cuda:0', grad_fn=<MseLossBackward0>)
# 800 tensor(1.0260, device='cuda:0', grad_fn=<MseLossBackward0>)
# 900 tensor(1.0202, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1000 tensor(1.1845, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1100 tensor(1.1702, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1200 tensor(1.1948, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1300 tensor(1.0134, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1400 tensor(1.0076, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1500 tensor(1.2452, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1600 tensor(0.9853, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1700 tensor(1.0758, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1800 tensor(1.1675, device='cuda:0', grad_fn=<MseLossBackward0>)
# 1900 tensor(0.9829, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2000 tensor(0.9051, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2100 tensor(1.0911, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2200 tensor(1.0909, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2300 tensor(1.0715, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2400 tensor(1.0682, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2500 tensor(1.0725, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2600 tensor(0.8864, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2700 tensor(1.1374, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2800 tensor(1.0154, device='cuda:0', grad_fn=<MseLossBackward0>)
# 2900 tensor(1.1016, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3000 tensor(0.9029, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3100 tensor(0.9508, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3200 tensor(0.9310, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3300 tensor(1.1918, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3400 tensor(1.1845, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3500 tensor(0.9249, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3600 tensor(0.9964, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3700 tensor(1.1915, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3800 tensor(0.9425, device='cuda:0', grad_fn=<MseLossBackward0>)
# 3900 tensor(0.9549, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4000 tensor(1.0289, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4100 tensor(0.9348, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4200 tensor(0.9545, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4300 tensor(0.9991, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4400 tensor(1.0247, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4500 tensor(0.9485, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4600 tensor(0.8843, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4700 tensor(0.9429, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4800 tensor(0.9497, device='cuda:0', grad_fn=<MseLossBackward0>)
# 4900 tensor(0.9678, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5000 tensor(1.1270, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5100 tensor(1.1401, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5200 tensor(0.9504, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5300 tensor(0.9930, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5400 tensor(0.9774, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5500 tensor(0.8603, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5600 tensor(1.0303, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5700 tensor(1.0362, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5800 tensor(1.2104, device='cuda:0', grad_fn=<MseLossBackward0>)
# 5900 tensor(0.9479, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6000 tensor(1.3263, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6100 tensor(1.0592, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6200 tensor(0.9117, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6300 tensor(0.8467, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6400 tensor(0.8434, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6500 tensor(1.0105, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6600 tensor(0.9153, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6700 tensor(1.0691, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6800 tensor(0.9818, device='cuda:0', grad_fn=<MseLossBackward0>)
# 6900 tensor(1.0787, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7000 tensor(0.8303, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7100 tensor(0.9365, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7200 tensor(1.0660, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7300 tensor(1.1474, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7400 tensor(1.0092, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7500 tensor(0.8985, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7600 tensor(0.9327, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7700 tensor(0.9972, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7800 tensor(0.9046, device='cuda:0', grad_fn=<MseLossBackward0>)
# 7900 tensor(1.1399, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8000 tensor(0.8118, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8100 tensor(1.1982, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8200 tensor(1.1540, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8300 tensor(0.9107, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8400 tensor(1.1938, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8500 tensor(1.0220, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8600 tensor(1.0300, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8700 tensor(1.2078, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8800 tensor(1.0599, device='cuda:0', grad_fn=<MseLossBackward0>)
# 8900 tensor(1.0250, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9000 tensor(1.0058, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9100 tensor(1.0067, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9200 tensor(1.0445, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9300 tensor(1.0232, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9400 tensor(1.1488, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9500 tensor(1.0408, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9600 tensor(1.2605, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9700 tensor(1.0655, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9800 tensor(0.9119, device='cuda:0', grad_fn=<MseLossBackward0>)
# 9900 tensor(0.8788, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10000 tensor(1.1009, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10100 tensor(1.1339, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10200 tensor(1.0875, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10300 tensor(0.7677, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10400 tensor(1.1677, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10500 tensor(1.0125, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10600 tensor(0.9666, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10700 tensor(0.9928, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10800 tensor(0.7865, device='cuda:0', grad_fn=<MseLossBackward0>)
# 10900 tensor(0.8720, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11000 tensor(0.8756, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11100 tensor(0.9739, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11200 tensor(0.8620, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11300 tensor(0.9273, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11400 tensor(0.8823, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11500 tensor(0.9212, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11600 tensor(0.8504, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11700 tensor(1.0236, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11800 tensor(0.9639, device='cuda:0', grad_fn=<MseLossBackward0>)
# 11900 tensor(1.0807, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12000 tensor(0.8049, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12100 tensor(0.9942, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12200 tensor(1.1261, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12300 tensor(0.8153, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12400 tensor(1.0877, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12500 tensor(0.7630, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12600 tensor(1.0961, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12700 tensor(1.1280, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12800 tensor(1.0645, device='cuda:0', grad_fn=<MseLossBackward0>)
# 12900 tensor(0.9591, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13000 tensor(1.0659, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13100 tensor(1.0962, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13200 tensor(0.9908, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13300 tensor(0.8616, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13400 tensor(0.9707, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13500 tensor(1.0061, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13600 tensor(1.0512, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13700 tensor(1.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13800 tensor(0.9816, device='cuda:0', grad_fn=<MseLossBackward0>)
# 13900 tensor(0.8996, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14000 tensor(1.0302, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14100 tensor(0.8367, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14200 tensor(0.9167, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14300 tensor(0.7439, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14400 tensor(0.9921, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14500 tensor(0.7610, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14600 tensor(1.0273, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14700 tensor(0.9977, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14800 tensor(0.7696, device='cuda:0', grad_fn=<MseLossBackward0>)
# 14900 tensor(0.7819, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15000 tensor(1.0063, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15100 tensor(1.0892, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15200 tensor(0.9923, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15300 tensor(0.8456, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15400 tensor(0.8370, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15500 tensor(0.8773, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15600 tensor(0.9565, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15700 tensor(0.7847, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15800 tensor(0.8325, device='cuda:0', grad_fn=<MseLossBackward0>)
# 15900 tensor(0.9699, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16000 tensor(0.8932, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16100 tensor(0.9963, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16200 tensor(0.9546, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16300 tensor(1.0537, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16400 tensor(0.8285, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16500 tensor(0.9101, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16600 tensor(1.0790, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16700 tensor(0.8285, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16800 tensor(1.1013, device='cuda:0', grad_fn=<MseLossBackward0>)
# 16900 tensor(0.9072, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17000 tensor(0.6497, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17100 tensor(1.0626, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17200 tensor(0.8483, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17300 tensor(0.9367, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17400 tensor(0.9807, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17500 tensor(0.8462, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17600 tensor(1.1336, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17700 tensor(0.9421, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17800 tensor(0.8961, device='cuda:0', grad_fn=<MseLossBackward0>)
# 17900 tensor(0.9744, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18000 tensor(0.9911, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18100 tensor(0.9752, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18200 tensor(0.9360, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18300 tensor(0.9549, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18400 tensor(0.9157, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18500 tensor(1.0511, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18600 tensor(0.8762, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18700 tensor(0.9704, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18800 tensor(0.8685, device='cuda:0', grad_fn=<MseLossBackward0>)
# 18900 tensor(0.9473, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19000 tensor(0.8973, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19100 tensor(0.9319, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19200 tensor(0.9033, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19300 tensor(1.0452, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19400 tensor(0.9588, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19500 tensor(0.9632, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19600 tensor(1.0521, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19700 tensor(1.0119, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19800 tensor(0.8254, device='cuda:0', grad_fn=<MseLossBackward0>)
# 19900 tensor(0.9907, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20000 tensor(0.9875, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20100 tensor(1.0279, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20200 tensor(0.9838, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20300 tensor(0.9137, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20400 tensor(0.8928, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20500 tensor(0.8906, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20600 tensor(0.9703, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20700 tensor(0.8271, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20800 tensor(0.8127, device='cuda:0', grad_fn=<MseLossBackward0>)
# 20900 tensor(0.8055, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21000 tensor(0.9794, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21100 tensor(0.8230, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21200 tensor(0.8156, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21300 tensor(0.6804, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21400 tensor(1.0611, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21500 tensor(0.8394, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21600 tensor(0.9839, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21700 tensor(0.9733, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21800 tensor(0.9684, device='cuda:0', grad_fn=<MseLossBackward0>)
# 21900 tensor(1.0261, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22000 tensor(1.0839, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22100 tensor(0.8549, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22200 tensor(1.0350, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22300 tensor(0.8711, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22400 tensor(1.1851, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22500 tensor(1.0869, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22600 tensor(1.0403, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22700 tensor(0.9633, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22800 tensor(0.9518, device='cuda:0', grad_fn=<MseLossBackward0>)
# 22900 tensor(1.0264, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23000 tensor(0.9288, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23100 tensor(0.9624, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23200 tensor(0.9872, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23300 tensor(0.9185, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23400 tensor(0.8578, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23500 tensor(0.8605, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23600 tensor(0.8072, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23700 tensor(1.0738, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23800 tensor(0.8566, device='cuda:0', grad_fn=<MseLossBackward0>)
# 23900 tensor(0.9140, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24000 tensor(0.8648, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24100 tensor(0.9041, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24200 tensor(0.8688, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24300 tensor(0.7794, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24400 tensor(0.8509, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24500 tensor(0.9825, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24600 tensor(0.8918, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24700 tensor(0.8939, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24800 tensor(1.0029, device='cuda:0', grad_fn=<MseLossBackward0>)
# 24900 tensor(1.0236, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25000 tensor(0.9868, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25100 tensor(0.9725, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25200 tensor(0.9288, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25300 tensor(0.8248, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25400 tensor(0.9570, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25500 tensor(0.8373, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25600 tensor(0.9155, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25700 tensor(0.8752, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25800 tensor(0.9813, device='cuda:0', grad_fn=<MseLossBackward0>)
# 25900 tensor(0.9696, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26000 tensor(0.9660, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26100 tensor(0.8560, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26200 tensor(0.9325, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26300 tensor(0.8152, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26400 tensor(0.8426, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26500 tensor(0.8915, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26600 tensor(0.7497, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26700 tensor(0.9783, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26800 tensor(0.8255, device='cuda:0', grad_fn=<MseLossBackward0>)
# 26900 tensor(0.8819, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27000 tensor(0.9581, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27100 tensor(0.9839, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27200 tensor(1.0290, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27300 tensor(1.0014, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27400 tensor(0.8713, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27500 tensor(0.8476, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27600 tensor(0.8662, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27700 tensor(0.9569, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27800 tensor(0.8440, device='cuda:0', grad_fn=<MseLossBackward0>)
# 27900 tensor(0.8677, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28000 tensor(1.0400, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28100 tensor(0.8537, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28200 tensor(0.9276, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28300 tensor(0.8062, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28400 tensor(0.8899, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28500 tensor(0.9881, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28600 tensor(1.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28700 tensor(0.7113, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28800 tensor(1.0204, device='cuda:0', grad_fn=<MseLossBackward0>)
# 28900 tensor(0.7800, device='cuda:0', grad_fn=<MseLossBackward0>)
# 29000 tensor(0.9935, device='cuda:0', grad_fn=<MseLossBackward0>)
# 29100 tensor(0.9888, device='cuda:0', grad_fn=<MseLossBackward0>)
# 29200 tensor(1.1275, device='cuda:0', grad_fn=<MseLossBackward0>)
# 29300 tensor(0.8127, device='cuda:0', grad_fn=<MseLossBackward0>)

# %%
from vit_pytorch.extractor import Extractor
v = Extractor(v)

# forward pass now returns predictions and the attention maps

img = torch.randn(1, 3, 256, 256)
logits, embeddings = v(img)

# %%
images = torch.randn(8, 3, 256, 256)

# %%
slides = torch.randint(0, 10, (8,))

# %%
loss = mae(images, slides)

# %%
loss
# Out:
# tensor(1.8420, grad_fn=<MseLossBackward0>)

# %%
loss.backward()
