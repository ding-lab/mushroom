# %%
import os
import re
import json
import pickle 
from pathlib import Path
import yaml

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scanpy as sc
import scipy
import skimage
import pandas as pd
import torch
import torchvision
import torchvision.transforms.functional as TF
import tifffile
from sklearn.metrics import adjusted_rand_score
from scipy.cluster.hierarchy import dendrogram
from einops import rearrange, repeat

# %%
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
plt.rcParams['svg.fonttype'] = 'none'

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import mushroom.utils as utils
import mushroom.data.multiplex as multiplex

# %% [markdown]
# ## DEG supp files

# %% [markdown]
# ###### automated 2D

# %%
fps = sorted(utils.listfiles(
    '/data/estorrs/mushroom/data/projects/submission_v1/analysis/region_characterization/results',
    regex=r'correlations_raw.txt'))

stacked = []
for fp in fps:
    name = fp.split('/')[-1]
    pattern = r'^([^_]+)_([^_]+)_([^_]+).*$'
    disease = re.sub(pattern, r'\1', name)
    dtype = re.sub(pattern, r'\2', name)
    rtype = re.sub(pattern, r'\3', name)

    source = pd.read_csv(fp, sep='\t', index_col=0)
    source['disease'] = disease
    source['dtype'] = dtype
    source['comparison_type'] = rtype
    stacked.append(source)
auto_2d_stat = pd.concat(stacked)
auto_2d_stat['gene'] = ['_'.join(x.split('_')[1:]) for x in auto_2d_stat['feature']]

auto_2d_stat
# Out:
#             case             sid         channel         feature  correlation  \
# 0        HT206B1     HT206B1-U15  boundary_ACTA2   boundary_AATK     0.042400
# 1        HT206B1     HT206B1-U15  boundary_ACTA2   boundary_ABL1     0.064535
# 2        HT206B1     HT206B1-U15  boundary_ACTA2   boundary_ABL2     0.117369
# 3        HT206B1     HT206B1-U15  boundary_ACTA2  boundary_ACACB     0.085246
# 4        HT206B1     HT206B1-U15  boundary_ACTA2    boundary_ACE     0.001241
# ...          ...             ...             ...             ...          ...
# 47069  S22-53426  S22-53426-A1U3   boundary_KRT5         tme_VIM    -0.022449
# 47070  S22-53426  S22-53426-A1U3   boundary_KRT5      tme_VPREB1    -0.019738
# 47071  S22-53426  S22-53426-A1U3   boundary_KRT5  tme_BLANK_0006    -0.005040
# 47072  S22-53426  S22-53426-A1U3   boundary_KRT5  tme_BLANK_0037    -0.018337
# 47073  S22-53426  S22-53426-A1U3   boundary_KRT5  tme_BLANK_0069     0.010159
#
#          pvalue disease   dtype comparison_type        gene
# 0      0.530644    brca   cosmx        boundary        AATK
# 1      0.339606    brca   cosmx        boundary        ABL1
# 2      0.081695    brca   cosmx        boundary        ABL2
# 3      0.206808    brca   cosmx        boundary       ACACB
# 4      0.985363    brca   cosmx        boundary         ACE
# ...         ...     ...     ...             ...         ...
# 47069  0.813425    prad  xenium             tme         VIM
# 47070  0.835614    prad  xenium             tme      VPREB1
# 47071  0.957751    prad  xenium             tme  BLANK_0006
# 47072  0.847138    prad  xenium             tme  BLANK_0037
# 47073  0.914953    prad  xenium             tme  BLANK_0069
#
# [445009 rows x 10 columns]

# %%
set(auto_2d_stat['dtype'])
# Out:
# {'cosmx', 'multiplex', 'vishd', 'xenium'}

# %% [markdown]
# ###### manual 2D

# %%
manual_2d_exp = pd.read_csv('/data/estorrs/mushroom/data/projects/submission_v1/analysis/region_characterization/results/manual_2d_exp.txt',
                      sep='\t', index_col=0)
manual_2d_exp
# Out:
#                                                     count       exp         z  \
# id
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...      1  0.000344  0.014235
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...     19  0.006543  0.270473
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...     54  0.018595  0.768714
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...     21  0.007231  0.298944
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...      4  0.001377  0.056942
# ...                                                   ...       ...       ...
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...    201  0.007366  0.244161
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...    455  0.016673  0.552704
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...     39  0.001429  0.047375
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...     48  0.001759  0.058307
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...     35  0.001283  0.042516
#
#                                                                sid   dtype  \
# id
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...      HT891Z1-U1  xenium
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...      HT891Z1-U1  xenium
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...      HT891Z1-U1  xenium
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...      HT891Z1-U1  xenium
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...      HT891Z1-U1  xenium
# ...                                                            ...     ...
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2  xenium
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2  xenium
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2  xenium
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2  xenium
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2  xenium
#
#                                                                                                   rid  \
# id
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...    HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...    HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...    HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...    HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...    HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5
# ...                                                                                               ...
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb86...
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb86...
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb86...
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb86...
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...  S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb86...
#
#                                                       gene annotation disease
# id
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...   ACKR1     normal    prad
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...   ACTA2     normal    prad
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...   ACTG2     normal    prad
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...  ADAM28     normal    prad
# HT891Z1-U1_bd656535-23c2-413a-b5f9-3c120ed43ae5...   ADAM8     normal    prad
# ...                                                    ...        ...     ...
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...    VCAN        gp3    prad
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...   VEGFA        gp3    prad
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...   VSIG4        gp3    prad
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...   VWA5A        gp3    prad
# S23-27043-A1U2_e810e3fa-7cbd-4dbe-b54f-1eaeb866...     VWF        gp3    prad
#
# [1074555 rows x 9 columns]

# %%
manual_2d_stat = pd.read_csv('/data/estorrs/mushroom/data/projects/submission_v1/analysis/region_characterization/results/manual_2d_stat.txt',
                              sep='\t')
manual_2d_stat
# Out:
#        disease   dtype  comparison       gene       stat        pvalue  \
# 0         brca  xenium  normal_idc       NAT8  17.056772  8.867908e-10
# 1         brca  xenium  normal_idc      ACTA2   7.501127  2.438563e-09
# 2         brca  xenium  normal_idc       SYNM  10.072110  7.995139e-09
# 3         brca  xenium  normal_idc  HNRNPA1L2  10.237435  6.216373e-09
# 4         brca  xenium  normal_idc      GTF2I   9.874708  1.083959e-08
# ...        ...     ...         ...        ...        ...           ...
# 132811    prad   vishd   hgpin_gp3       NOD1   0.000918  9.992897e-01
# 132812    prad   vishd   hgpin_gp3   ARHGEF35   0.001016  9.992144e-01
# 132813    prad   vishd   hgpin_gp3      SMIM1  -0.000714  9.994478e-01
# 132814    prad   vishd   hgpin_gp3      GRTP1   0.000781  9.993960e-01
# 132815    prad   vishd   hgpin_gp3    CAMSAP3   0.000304  9.997647e-01
#
#         pvalue_fdr
# 0         0.000004
# 1         0.000006
# 2         0.000010
# 3         0.000010
# 4         0.000011
# ...            ...
# 132811    0.999482
# 132812    0.999482
# 132813    0.999512
# 132814    0.999512
# 132815    0.999765
#
# [132816 rows x 7 columns]

# %% [markdown]
# ###### manual 3D

# %%
fps = []
for case in ['HT704B1', 'HT206B1', 'HT891Z1', 'HT913Z1']:
    fps += sorted(utils.listfiles(
        f'/data/estorrs/mushroom/data/projects/submission_v1/{case}/imaris/rois/regions',
        regex=r'json$')
    )
    
case_to_roi_to_data = {}
for fp in fps:
    d = json.load(open(fp))
    data = {
        'rids': d['region_ids'],
        'sids': d['sids'],
        'rid_to_patho': d['region_id_to_pathology']
    }

    case = fp.split('/')[-5]
    roi = fp.split('/')[-1].split('_')[0]

    if case not in case_to_roi_to_data:
        case_to_roi_to_data[case] = {}

    case_to_roi_to_data[case][roi] = data

# %%
ignore = [('HT206B1', 'roi3'), ('HT891Z1', 'roi2-p2'), ('HT913Z1', 'roi1-p2')]

# %%
fps = []
for case in ['HT704B1', 'HT206B1', 'HT891Z1', 'HT913Z1']:
    fps += sorted(utils.listfiles(
        f'/data/estorrs/mushroom/data/projects/submission_v1/{case}/imaris/rois/results',
        regex=r'_expression.txt.gz')
    )
fps = [fp for fp in fps if 'tme' not in fp]

stacked = []
for fp in fps:
    case = fp.split('/')[-5]
    df = pd.read_csv(fp, sep='\t')

    name = fp.split('/')[-1]
    pattern = r'^([^_]+)_(.+)_([^_]+).txt.gz$'
    roi = re.sub(pattern, r'\1', name)
    dti = re.sub(pattern, r'\2', name)

    if (case, roi) not in ignore and 'combined' not in dti:    
        df['disease'] = 'breast' if 'B1' in case else 'prostate'
        df['case'] = case
        df['roi'] = roi
        df['dtype_identifier'] = dti
        df['dtype'] = dti.split('_')[0]
    
        data = case_to_roi_to_data[case][roi]
        df['region_index'] = [data['rids'].index(x) for x in df['region_id']]
        df['sample_id'] = [data['sids'][i] for i in df['region_index']]
        df['annotation'] = [data['rid_to_patho'][x] for x in df['region_id']]
        
        
        
        df = df.melt(id_vars=['disease', 'case', 'roi', 'region_id', 'dtype', 'dtype_identifier', 'region_index', 'sample_id', 'annotation'])
        df.columns = list(df.columns)[:-2] + ['gene', 'expression']
        stacked.append(df)
manual_3d_exp = pd.concat(stacked)
manual_3d_exp
# Out:
#        disease     case   roi                             region_id   dtype  \
# 0       breast  HT704B1  roi1  25f59172-9dc6-4340-a21f-2a2b557176cf   cosmx
# 1       breast  HT704B1  roi1  a4719551-76dd-4117-a82a-c086568f52f2   cosmx
# 2       breast  HT704B1  roi1  7ee62508-a502-404f-b93c-47d0fa181aab   cosmx
# 3       breast  HT704B1  roi1  25f59172-9dc6-4340-a21f-2a2b557176cf   cosmx
# 4       breast  HT704B1  roi1  a4719551-76dd-4117-a82a-c086568f52f2   cosmx
# ...        ...      ...   ...                                   ...     ...
# 2851  prostate  HT913Z1  roi1  734069e4-66e4-4a0c-93ee-115a1cb6e4c0  xenium
# 2852  prostate  HT913Z1  roi1  611c1c4c-4c78-407f-9592-994e87ee0ca0  xenium
# 2853  prostate  HT913Z1  roi1  1215ccaf-0c17-4f34-a945-4fafeb196884  xenium
# 2854  prostate  HT913Z1  roi1  6d6519b0-a5cc-4a41-b123-69bcc04fb956  xenium
# 2855  prostate  HT913Z1  roi1  1ff275e0-c951-4067-b7f9-cc72f7543230  xenium
#
#      dtype_identifier  region_index     sample_id annotation  gene  expression
# 0             cosmx_0             4   HT704B1-U14       DCIS  AATK    1.260581
# 1             cosmx_0            21   HT704B1-U47        IDC  AATK    1.742139
# 2             cosmx_0            27   HT704B1-U56        IDC  AATK    1.425868
# 3             cosmx_0             4   HT704B1-U14       DCIS  ABL1    1.482688
# 4             cosmx_0            21   HT704B1-U47        IDC  ABL1    1.617586
# ...               ...           ...           ...        ...   ...         ...
# 2851         xenium_1            20   HT913Z1-U34     Normal   VWF    0.010736
# 2852         xenium_1            21   HT913Z1-U35     Normal   VWF    0.035741
# 2853         xenium_1            37   HT913Z1-U61     Normal   VWF    0.021357
# 2854         xenium_1            49   HT913Z1-U81     Normal   VWF    0.243129
# 2855         xenium_1            60  HT913Z1-U101     Normal   VWF    0.000000
#
# [210610 rows x 11 columns]

# %%
fps = []
for case in ['HT704B1', 'HT206B1', 'HT891Z1', 'HT913Z1']:
    fps += sorted(utils.listfiles(
        f'/data/estorrs/mushroom/data/projects/submission_v1/{case}/imaris/rois/results',
        regex=r'_fc.txt.gz')
    )
fps = [fp for fp in fps if 'tme' not in fp]

stacked = []
for fp in fps:
    case = fp.split('/')[-5]
    df = pd.read_csv(fp, sep='\t')
    
    name = fp.split('/')[-1]
    pattern = r'^([^_]+)_(.+)_([^_]+).txt.gz$'
    roi = re.sub(pattern, r'\1', name)
    dti = re.sub(pattern, r'\2', name)

    if (case, roi) not in ignore and 'combined' not in dti:    
        df['disease'] = 'breast' if 'B1' in case else 'prostate'
        df['case'] = case
        df['roi'] = roi
        df['dtype_identifier'] = dti
        df['dtype'] = dti.split('_')[0]
        df['transition_id'] = [x.replace('IDC - partial', 'MI') for x in df['transition_id']]

        df = df.melt(id_vars=['disease', 'case', 'roi', 'dtype', 'dtype_identifier', 'transition_id'])
        df.columns = list(df.columns)[:-2] + ['gene', 'fc']
        stacked.append(df)
manual_3d_fc = pd.concat(stacked)
manual_3d_fc
# Out:
#       disease     case   roi   dtype dtype_identifier  transition_id    gene  \
# 0      breast  HT704B1  roi1  xenium         xenium_0        DCIS_MI  ABCC11
# 1      breast  HT704B1  roi1  xenium         xenium_0         MI_IDC  ABCC11
# 2      breast  HT704B1  roi1  xenium         xenium_0        DCIS_MI    ACE2
# 3      breast  HT704B1  roi1  xenium         xenium_0         MI_IDC    ACE2
# 4      breast  HT704B1  roi1  xenium         xenium_0        DCIS_MI   ACKR1
# ..        ...      ...   ...     ...              ...            ...     ...
# 947  prostate  HT891Z1  roi2  xenium         xenium_0     HG PIN_GP3   VSIG4
# 948  prostate  HT891Z1  roi2  xenium         xenium_0  Normal_HG PIN   VWA5A
# 949  prostate  HT891Z1  roi2  xenium         xenium_0     HG PIN_GP3   VWA5A
# 950  prostate  HT891Z1  roi2  xenium         xenium_0  Normal_HG PIN     VWF
# 951  prostate  HT891Z1  roi2  xenium         xenium_0     HG PIN_GP3     VWF
#
#            fc
# 0   -0.246402
# 1    0.015119
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 947       NaN
# 948 -0.306108
# 949       NaN
# 950       NaN
# 951       NaN
#
# [56314 rows x 8 columns]

# %% [markdown]
# ## save them all

# %%
directory = Path('/data/estorrs/mushroom/data/projects/submission_v1/supplement')
directory.mkdir(parents=True, exist_ok=True)
directory
# Out:
# PosixPath('/data/estorrs/mushroom/data/projects/submission_v1/supplement')

# %%
auto_2d_stat.to_csv(directory / 'automated_2d_correlations.txt', sep='\t', index=False)
manual_2d_exp.to_csv(directory / 'manual_2d_exp.txt', sep='\t')
manual_2d_stat.to_csv(directory / 'manual_2d_stat.txt', sep='\t', index=False)
manual_3d_exp.to_csv(directory / 'manual_3d_exp.txt', sep='\t', index=False)
manual_3d_fc.to_csv(directory / 'manual_3d_fc.txt', sep='\t', index=False)

# %% [markdown]
# ## section metadata table

# %%
cases_3d = [
    'HT206B1',
    'HT397B1',
    'HT704B1',
    'HT891Z1',
    'HT913Z1',
    'HT339B2-H1',
    'HT565B1-H2',
    'S18-5591-C8',
    'S18-9906'
]

source_root = '/diskmnt/Projects/Users/estorrs/mushroom/data'
target_root = '/data/estorrs/mushroom/data'

def alter_filesystem(config, source_root, target_root):
    for entry in config['sections']:
        for mapping in entry['data']:
            mapping['filepath'] = mapping['filepath'].replace(source_root, target_root)
    
    if 'trainer_kwargs' in config and config['trainer_kwargs']['data_mask'] is not None:
        config['trainer_kwargs']['data_mask'] = config['trainer_kwargs']['data_mask'].replace(source_root, target_root)
        
    return config

case_to_config = {}
for case in cases_3d:
    project_dir = Path(f'/data/estorrs/mushroom/data/projects/submission_v1/{case}')
    config = yaml.safe_load(open(os.path.join(project_dir, 'registered', 'metadata.yaml')))
    config = alter_filesystem(config, source_root, target_root)
    case_to_config[case] = config

# %%
to_renamed = {line.split('\t')[0]:line.split('\t')[1] for line in """S18-11798	SP003Z1-Fp1
S18-15142	SP004Z1-Fp1
S18-18215	SP005Z1-Fp1
S18-5591	SP006Z1-Fp1
S18-8795	SP007Z1-Fp1
S18-9251	SP008Z1-Fp1
S18-9259	SP009Z1-Fp1
S19-41530	SP010Z1-Fp1
S20-12521	SP011Z1-Fp1
S21-11816	SP012Z1-Fp1
S21-44455	SP013Z1-Fp1
S22-44238	SP014Z1-Fp1
S22-53426	SP015Z1-Fp1
S18-8122	SP016Z1-Fp1
S18-9906	SP017Z1-Fp1""".split('\n')}

# %%
def alter_dtype(x):
    if 'batch' in x:
        return 'he'
    if x == 'multiplex':
        return 'codex'
    if x == 'vishd':
        return 'visiumhd'
    return x


data = []
for case, config in case_to_config.items():
    config = case_to_config[case]
    if 'HT' in case:
        case = re.sub(r'^(HT[0-9]+[BZ][0-9]).*$', r'\1', case)
    else:
        case = re.sub(r'^(S[0-9]+-[0-9]+).*$', r'\1', case)

    for entry in config['sections']:
        mapping = entry['data'][0]

        if case in to_renamed:
            renamed_case = to_renamed[case]
            renamed_case = renamed_case.replace('-Fp1', '')
            sid = entry['sid'].replace(case, renamed_case)
        else:
            renamed_case = case
            sid = entry['sid']
        
        data.append([renamed_case, sid, entry['position'], mapping['dtype'], mapping['filepath']])
meta = pd.DataFrame(data=data, columns=['case', 'section_id', 'z_depth', 'dtype', 'filepath'])

meta['dtype'] = [alter_dtype(x) for x in meta['dtype']]
meta['cohort'] = '3d'
meta['disease'] = ['prostate' if 'Z' in case else 'breast' for case in meta['case']]
meta
# Out:
#         case   section_id  z_depth   dtype  \
# 0    HT206B1   HT206B1-U1        0  xenium
# 1    HT206B1   HT206B1-U4        5      he
# 2    HT206B1   HT206B1-U2       15   codex
# 3    HT206B1   HT206B1-U5       20   codex
# 4    HT206B1   HT206B1-U8       40  xenium
# ..       ...          ...      ...     ...
# 228  SP017Z1  SP017Z1-U17      120  xenium
# 229  SP017Z1  SP017Z1-U18      125   codex
# 230  SP017Z1  SP017Z1-U20      135      he
# 231  SP017Z1  SP017Z1-U24      155  xenium
# 232  SP017Z1  SP017Z1-U25      160   codex
#
#                                               filepath cohort   disease
# 0    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 1    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 2    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 3    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 4    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# ..                                                 ...    ...       ...
# 228  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 229  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 230  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 231  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 232  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
#
# [233 rows x 7 columns]

# %%
sids_2d = [x for x in sorted(set(auto_2d_stat['sid'])) if not any([c in x for c in cases_3d])]
sids_2d = [x for x in sids_2d if 'HT268' not in x]

data = []
for sid in sids_2d:
    if 'HT' in sid:
        case = re.sub(r'^(HT[0-9]+[BZ][0-9]).*$', r'\1', sid)
        rest = re.sub(r'^(HT[0-9]+[BZ][0-9])(.*)$', r'\2', sid)
    else:
        case = re.sub(r'^(S[0-9]+-[0-9]+).*$', r'\1', sid)
        rest = re.sub(r'^(S[0-9]+-[0-9]+)(.*)$', r'\2', sid)
        case = to_renamed.get(case, case)
        sid = case
        case = case.replace('-Fp1', '')
    data.append([case, sid, np.nan, 'xenium', None, '2d', 'prostate' if 'Z' in case else 'breast'])
meta_2d = pd.DataFrame(data=data, columns=['case', 'section_id', 'z_depth', 'dtype', 'filepath', 'cohort', 'disease'])
meta = pd.concat((meta, meta_2d))

# %%
for x in sids_2d: print(x)
# Out:
# HT591B1-S1H1Fp1Us1_1
# HT814Z1-S1H1Fp1Us1_3
# HT817Z1-S1H1Fp1Us1_2
# HT832Z1-S1H1Fp1U1
# HT832Z1U1
# HT849Z1-S1H2Fp1U1
# HT852Z1-S1H1Fp1U1
# S18-11798-A15Us1_1
# S18-15142-B17Us2_1
# S18-15142Fp1Us1_1
# S18-18215-A25Us1_1
# S18-8122-B28U1
# S18-8795-A10Us2_1
# S18-9251-F15U1
# S18-9259-B14U1
# S19-41530-D1U3
# S20-12521-A15U1
# S21-11816-A2U3
# S21-44455-A1U3
# S22-44238-A29U1
# S22-53426-A1U3

# %%
meta = meta.sort_values(['disease', 'case', 'z_depth'])
meta
# Out:
#         case   section_id  z_depth   dtype  \
# 0    HT206B1   HT206B1-U1      0.0  xenium
# 1    HT206B1   HT206B1-U4      5.0      he
# 2    HT206B1   HT206B1-U2     15.0   codex
# 3    HT206B1   HT206B1-U5     20.0   codex
# 4    HT206B1   HT206B1-U8     40.0  xenium
# ..       ...          ...      ...     ...
# 228  SP017Z1  SP017Z1-U17    120.0  xenium
# 229  SP017Z1  SP017Z1-U18    125.0   codex
# 230  SP017Z1  SP017Z1-U20    135.0      he
# 231  SP017Z1  SP017Z1-U24    155.0  xenium
# 232  SP017Z1  SP017Z1-U25    160.0   codex
#
#                                               filepath cohort   disease
# 0    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 1    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 2    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 3    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 4    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# ..                                                 ...    ...       ...
# 228  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 229  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 230  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 231  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 232  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
#
# [254 rows x 7 columns]

# %%
meta.to_csv(directory / 'section_metadata.txt', sep='\t', index=False)

# %%
dtypes = sorted(set(meta['dtype']))
for dtype in dtypes:
    f = meta[meta['dtype']==dtype]
    print(dtype, len(set(f['case'])), f.shape[0])
# Out:
# codex 9 66
# cosmx 3 7
# he 7 110
# visium 4 6
# visiumhd 2 4
# xenium 25 61

# %%
diseases = sorted(set(meta['disease']))
for disease in diseases:
    f = meta[meta['disease']==disease]
    print(disease, len(set(f['case'])), f.shape[0])
# Out:
# breast 6 77
# prostate 22 177

# %%
cohorts = sorted(set(meta['cohort']))
for cohort in cohorts:
    f = meta[meta['cohort']==cohort]
    print(cohort, len(set(f['case'])), f.shape[0])
# Out:
# 2d 19 21
# 3d 9 233

# %%
cohorts = sorted(set(meta['cohort']))
for cohort in cohorts:
    for disease in diseases:
        f = meta[((meta['cohort']==cohort)&(meta['disease']==disease))]
        print(cohort, disease, len(set(f['case'])), f.shape[0])
# Out:
# 2d breast 1 1
# 2d prostate 18 20
# 3d breast 5 76
# 3d prostate 4 157

# %%
for case in sorted(set(meta['case'])):
    f = meta[meta['case']==case]
    for dtype in dtypes:
        z = f[f['dtype']==dtype]
        print(case, dtype, z.shape[0])
# Out:
# HT206B1 codex 6
# HT206B1 cosmx 1
# HT206B1 he 3
# HT206B1 visium 0
# HT206B1 visiumhd 0
# HT206B1 xenium 6
# HT339B2 codex 1
# HT339B2 cosmx 0
# HT339B2 he 0
# HT339B2 visium 1
# HT339B2 visiumhd 0
# HT339B2 xenium 0
# HT397B1 codex 4
# HT397B1 cosmx 0
# HT397B1 he 6
# HT397B1 visium 2
# HT397B1 visiumhd 0
# HT397B1 xenium 0
# HT565B1 codex 1
# HT565B1 cosmx 0
# HT565B1 he 0
# HT565B1 visium 1
# HT565B1 visiumhd 0
# HT565B1 xenium 0
# HT591B1 codex 0
# HT591B1 cosmx 0
# HT591B1 he 0
# HT591B1 visium 0
# HT591B1 visiumhd 0
# HT591B1 xenium 1
# HT704B1 codex 12
# HT704B1 cosmx 4
# HT704B1 he 20
# HT704B1 visium 0
# HT704B1 visiumhd 2
# HT704B1 xenium 6
# HT814Z1 codex 0
# HT814Z1 cosmx 0
# HT814Z1 he 0
# HT814Z1 visium 0
# HT814Z1 visiumhd 0
# HT814Z1 xenium 1
# HT817Z1 codex 0
# HT817Z1 cosmx 0
# HT817Z1 he 0
# HT817Z1 visium 0
# HT817Z1 visiumhd 0
# HT817Z1 xenium 1
# HT832Z1 codex 0
# HT832Z1 cosmx 0
# HT832Z1 he 0
# HT832Z1 visium 0
# HT832Z1 visiumhd 0
# HT832Z1 xenium 2
# HT849Z1 codex 0
# HT849Z1 cosmx 0
# HT849Z1 he 0
# HT849Z1 visium 0
# HT849Z1 visiumhd 0
# HT849Z1 xenium 1
# HT852Z1 codex 0
# HT852Z1 cosmx 0
# HT852Z1 he 0
# HT852Z1 visium 0
# HT852Z1 visiumhd 0
# HT852Z1 xenium 1
# HT891Z1 codex 16
# HT891Z1 cosmx 2
# HT891Z1 he 25
# HT891Z1 visium 0
# HT891Z1 visiumhd 2
# HT891Z1 xenium 9
# HT913Z1 codex 16
# HT913Z1 cosmx 0
# HT913Z1 he 51
# HT913Z1 visium 0
# HT913Z1 visiumhd 0
# HT913Z1 xenium 9
# SP003Z1 codex 0
# SP003Z1 cosmx 0
# SP003Z1 he 0
# SP003Z1 visium 0
# SP003Z1 visiumhd 0
# SP003Z1 xenium 1
# SP004Z1 codex 0
# SP004Z1 cosmx 0
# SP004Z1 he 0
# SP004Z1 visium 0
# SP004Z1 visiumhd 0
# SP004Z1 xenium 2
# SP005Z1 codex 0
# SP005Z1 cosmx 0
# SP005Z1 he 0
# SP005Z1 visium 0
# SP005Z1 visiumhd 0
# SP005Z1 xenium 1
# SP006Z1 codex 6
# SP006Z1 cosmx 0
# SP006Z1 he 2
# SP006Z1 visium 0
# SP006Z1 visiumhd 0
# SP006Z1 xenium 6
# SP007Z1 codex 0
# SP007Z1 cosmx 0
# SP007Z1 he 0
# SP007Z1 visium 0
# SP007Z1 visiumhd 0
# SP007Z1 xenium 1
# SP008Z1 codex 0
# SP008Z1 cosmx 0
# SP008Z1 he 0
# SP008Z1 visium 0
# SP008Z1 visiumhd 0
# SP008Z1 xenium 1
# SP009Z1 codex 0
# SP009Z1 cosmx 0
# SP009Z1 he 0
# SP009Z1 visium 0
# SP009Z1 visiumhd 0
# SP009Z1 xenium 1
# SP010Z1 codex 0
# SP010Z1 cosmx 0
# SP010Z1 he 0
# SP010Z1 visium 0
# SP010Z1 visiumhd 0
# SP010Z1 xenium 1
# SP011Z1 codex 0
# SP011Z1 cosmx 0
# SP011Z1 he 0
# SP011Z1 visium 0
# SP011Z1 visiumhd 0
# SP011Z1 xenium 1
# SP012Z1 codex 0
# SP012Z1 cosmx 0
# SP012Z1 he 0
# SP012Z1 visium 0
# SP012Z1 visiumhd 0
# SP012Z1 xenium 1
# SP013Z1 codex 0
# SP013Z1 cosmx 0
# SP013Z1 he 0
# SP013Z1 visium 0
# SP013Z1 visiumhd 0
# SP013Z1 xenium 1
# SP014Z1 codex 0
# SP014Z1 cosmx 0
# SP014Z1 he 0
# SP014Z1 visium 0
# SP014Z1 visiumhd 0
# SP014Z1 xenium 1
# SP015Z1 codex 0
# SP015Z1 cosmx 0
# SP015Z1 he 0
# SP015Z1 visium 0
# SP015Z1 visiumhd 0
# SP015Z1 xenium 1
# SP016Z1 codex 0
# SP016Z1 cosmx 0
# SP016Z1 he 0
# SP016Z1 visium 0
# SP016Z1 visiumhd 0
# SP016Z1 xenium 1
# SP017Z1 codex 4
# SP017Z1 cosmx 0
# SP017Z1 he 3
# SP017Z1 visium 2
# SP017Z1 visiumhd 0
# SP017Z1 xenium 4

# %%
for x in sorted(set(meta['case'])): print(x)
# Out:
# HT206B1
# HT339B2
# HT397B1
# HT565B1
# HT591B1
# HT704B1
# HT814Z1
# HT817Z1
# HT832Z1
# HT849Z1
# HT852Z1
# HT891Z1
# HT913Z1
# SP003Z1
# SP004Z1
# SP005Z1
# SP006Z1
# SP007Z1
# SP008Z1
# SP009Z1
# SP010Z1
# SP011Z1
# SP012Z1
# SP013Z1
# SP014Z1
# SP015Z1
# SP016Z1
# SP017Z1

# %%
for x in meta[meta['cohort']=='2d']['case'].to_list(): print(x)
# Out:
# HT591B1
# HT814Z1
# HT817Z1
# HT832Z1
# HT832Z1
# HT849Z1
# HT852Z1
# SP003Z1
# SP004Z1
# SP004Z1
# SP005Z1
# SP007Z1
# SP008Z1
# SP009Z1
# SP010Z1
# SP011Z1
# SP012Z1
# SP013Z1
# SP014Z1
# SP015Z1
# SP016Z1

# %%
meta[meta['cohort']=='2d']
# Out:
#        case            section_id  z_depth   dtype filepath cohort   disease
# 0   HT591B1  HT591B1-S1H1Fp1Us1_1      NaN  xenium     None     2d    breast
# 1   HT814Z1  HT814Z1-S1H1Fp1Us1_3      NaN  xenium     None     2d  prostate
# 2   HT817Z1  HT817Z1-S1H1Fp1Us1_2      NaN  xenium     None     2d  prostate
# 3   HT832Z1     HT832Z1-S1H1Fp1U1      NaN  xenium     None     2d  prostate
# 4   HT832Z1             HT832Z1U1      NaN  xenium     None     2d  prostate
# 5   HT849Z1     HT849Z1-S1H2Fp1U1      NaN  xenium     None     2d  prostate
# 6   HT852Z1     HT852Z1-S1H1Fp1U1      NaN  xenium     None     2d  prostate
# 7   SP003Z1           SP003Z1-Fp1      NaN  xenium     None     2d  prostate
# 8   SP004Z1           SP004Z1-Fp1      NaN  xenium     None     2d  prostate
# 9   SP004Z1           SP004Z1-Fp1      NaN  xenium     None     2d  prostate
# 10  SP005Z1           SP005Z1-Fp1      NaN  xenium     None     2d  prostate
# 12  SP007Z1           SP007Z1-Fp1      NaN  xenium     None     2d  prostate
# 13  SP008Z1           SP008Z1-Fp1      NaN  xenium     None     2d  prostate
# 14  SP009Z1           SP009Z1-Fp1      NaN  xenium     None     2d  prostate
# 15  SP010Z1           SP010Z1-Fp1      NaN  xenium     None     2d  prostate
# 16  SP011Z1           SP011Z1-Fp1      NaN  xenium     None     2d  prostate
# 17  SP012Z1           SP012Z1-Fp1      NaN  xenium     None     2d  prostate
# 18  SP013Z1           SP013Z1-Fp1      NaN  xenium     None     2d  prostate
# 19  SP014Z1           SP014Z1-Fp1      NaN  xenium     None     2d  prostate
# 20  SP015Z1           SP015Z1-Fp1      NaN  xenium     None     2d  prostate
# 11  SP016Z1           SP016Z1-Fp1      NaN  xenium     None     2d  prostate

# %% [markdown]
# ## CODEX panel info

# %%
meta = pd.read_csv(directory / 'section_metadata.txt', sep='\t')
meta
# Out:
#         case   section_id  z_depth   dtype  \
# 0    HT206B1   HT206B1-U1      0.0  xenium
# 1    HT206B1   HT206B1-U4      5.0      he
# 2    HT206B1   HT206B1-U2     15.0   codex
# 3    HT206B1   HT206B1-U5     20.0   codex
# 4    HT206B1   HT206B1-U8     40.0  xenium
# ..       ...          ...      ...     ...
# 249  SP017Z1  SP017Z1-U17    120.0  xenium
# 250  SP017Z1  SP017Z1-U18    125.0   codex
# 251  SP017Z1  SP017Z1-U20    135.0      he
# 252  SP017Z1  SP017Z1-U24    155.0  xenium
# 253  SP017Z1  SP017Z1-U25    160.0   codex
#
#                                               filepath cohort   disease
# 0    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 1    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 2    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 3    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 4    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# ..                                                 ...    ...       ...
# 249  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 250  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 251  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 252  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 253  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
#
# [254 rows x 7 columns]

# %%
f = meta[meta['dtype']=='codex']
f
# Out:
#         case      section_id  z_depth  dtype  \
# 2    HT206B1      HT206B1-U2     15.0  codex
# 3    HT206B1      HT206B1-U5     20.0  codex
# 6    HT206B1     HT206B1-U10     50.0  codex
# 8    HT206B1     HT206B1-U13     65.0  codex
# 12   HT206B1     HT206B1-U18     90.0  codex
# ..       ...             ...      ...    ...
# 230  SP006Z1  SP006Z1-C8-U24    115.0  codex
# 243  SP017Z1      SP017Z1-U3     10.0  codex
# 246  SP017Z1     SP017Z1-U10     45.0  codex
# 250  SP017Z1     SP017Z1-U18    125.0  codex
# 253  SP017Z1     SP017Z1-U25    160.0  codex
#
#                                               filepath cohort   disease
# 2    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 3    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 6    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 8    /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# 12   /data/estorrs/mushroom/data/projects/submissio...     3d    breast
# ..                                                 ...    ...       ...
# 230  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 243  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 246  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 250  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
# 253  /data/estorrs/mushroom/data/projects/submissio...     3d  prostate
#
# [66 rows x 7 columns]

# %%
# we need to add validation samples

temp = pd.DataFrame(data=[
    ['HT323B1', 'HT323B1-H1A4', np.nan, 'codex', '/data/estorrs/sandbox/mushroom/codex/HT323B1-H1A4__20220210.ome.tiff', 'validation', 'breast'],
    ['HT110B1', 'HT110B1-S1H4', np.nan, 'codex', '/data/estorrs/sandbox/mushroom/codex/HT110B1-S1H4__20221216.ome.tiff', 'validation', 'breast'],
], columns=['case', 'section_id', 'z_depth', 'dtype', 'filepath', 'cohort', 'disease'])
f = pd.concat((f, temp))
f
# Out:
#        case    section_id  z_depth  dtype  \
# 0   HT206B1    HT206B1-U2     15.0  codex
# 1   HT206B1    HT206B1-U5     20.0  codex
# 2   HT206B1   HT206B1-U10     50.0  codex
# 3   HT206B1   HT206B1-U13     65.0  codex
# 4   HT206B1   HT206B1-U18     90.0  codex
# ..      ...           ...      ...    ...
# 63  SP017Z1   SP017Z1-U10     45.0  codex
# 64  SP017Z1   SP017Z1-U18    125.0  codex
# 65  SP017Z1   SP017Z1-U25    160.0  codex
# 0   HT323B1  HT323B1-H1A4      NaN  codex
# 1   HT110B1  HT110B1-S1H4      NaN  codex
#
#                                              filepath      cohort   disease
# 0   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# 1   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# 2   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# 3   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# 4   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# ..                                                ...         ...       ...
# 63  /data/estorrs/mushroom/data/projects/submissio...          3d  prostate
# 64  /data/estorrs/mushroom/data/projects/submissio...          3d  prostate
# 65  /data/estorrs/mushroom/data/projects/submissio...          3d  prostate
# 0   /data/estorrs/sandbox/mushroom/codex/HT323B1-H...  validation    breast
# 1   /data/estorrs/sandbox/mushroom/codex/HT110B1-S...  validation    breast
#
# [68 rows x 7 columns]

# %%
channel_xs = []
for i, row in f.iterrows():
    channels = multiplex.get_ome_tiff_channels(row['filepath'])
    channel_xs.append(channels)

max_n = np.max([len(x) for x in channel_xs])

tail = np.empty((len(channel_xs), max_n), dtype=object)

for i, channels in enumerate(channel_xs):
    tail[i, :len(channels)] = channels

cols = [f'channel_{i}' for i in range(max_n)]
tail = pd.DataFrame(data=tail, columns=cols)

f.index = list(range(f.shape[0]))

codex_table = pd.concat((f, tail), axis=1)
codex_table
# Out:
#        case    section_id  z_depth  dtype  \
# 0   HT206B1    HT206B1-U2     15.0  codex
# 1   HT206B1    HT206B1-U5     20.0  codex
# 2   HT206B1   HT206B1-U10     50.0  codex
# 3   HT206B1   HT206B1-U13     65.0  codex
# 4   HT206B1   HT206B1-U18     90.0  codex
# ..      ...           ...      ...    ...
# 63  SP017Z1   SP017Z1-U10     45.0  codex
# 64  SP017Z1   SP017Z1-U18    125.0  codex
# 65  SP017Z1   SP017Z1-U25    160.0  codex
# 66  HT323B1  HT323B1-H1A4      NaN  codex
# 67  HT110B1  HT110B1-S1H4      NaN  codex
#
#                                              filepath      cohort   disease  \
# 0   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# 1   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# 2   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# 3   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# 4   /data/estorrs/mushroom/data/projects/submissio...          3d    breast
# ..                                                ...         ...       ...
# 63  /data/estorrs/mushroom/data/projects/submissio...          3d  prostate
# 64  /data/estorrs/mushroom/data/projects/submissio...          3d  prostate
# 65  /data/estorrs/mushroom/data/projects/submissio...          3d  prostate
# 66  /data/estorrs/sandbox/mushroom/codex/HT323B1-H...  validation    breast
# 67  /data/estorrs/sandbox/mushroom/codex/HT110B1-S...  validation    breast
#
#    channel_0   channel_1   channel_2  ... channel_28 channel_29  channel_30  \
# 0       DAPI  Granzyme B   Keratin 5  ...   Vimentin       CD31  E-cadherin
# 1       DAPI  Granzyme B   Keratin 5  ...   Vimentin       CD3e  E-cadherin
# 2       DAPI  Granzyme B   Keratin 5  ...   Vimentin       CD31  E-cadherin
# 3       DAPI  Granzyme B   Keratin 5  ...   Vimentin       CD3e  E-cadherin
# 4       DAPI  Granzyme B   Keratin 5  ...   Vimentin       CD31  E-cadherin
# ..       ...         ...         ...  ...        ...        ...         ...
# 63      DAPI        CK14       LYVE1  ...       None       None        None
# 64      DAPI        CK14       LYVE1  ...       None       None        None
# 65      DAPI        CK14       LYVE1  ...       None       None        None
# 66      DAPI        CD31  E-cadherin  ...       CD36       CK14       CD11c
# 67      DAPI         CD8       CD138  ...       None       None        None
#
#    channel_31 channel_32 channel_33 channel_34 channel_35 channel_36  \
# 0     SMA (D)      cd11b     PR (D)   CD45 (D)         ER  COX6C (D)
# 1     SMA (D)      cd11b     PR (D)   CD45 (D)       CD31  GATA3 (D)
# 2     SMA (D)      cd11b     PR (D)   CD45 (D)         ER  COX6C (D)
# 3     SMA (D)      cd11b     PR (D)   CD45 (D)       CD31  GATA3 (D)
# 4     SMA (D)      cd11b     PR (D)   CD45 (D)         ER  COX6C (D)
# ..        ...        ...        ...        ...        ...        ...
# 63       None       None       None       None       None       None
# 64       None       None       None       None       None       None
# 65       None       None       None       None       None       None
# 66       CD44       None       None       None       None       None
# 67       None       None       None       None       None       None
#
#    channel_37
# 0        None
# 1   COX6C (D)
# 2        None
# 3   COX6C (D)
# 4        None
# ..        ...
# 63       None
# 64       None
# 65       None
# 66       None
# 67       None
#
# [68 rows x 45 columns]

# %%
codex_table.to_csv(directory / 'codex_metadata.txt', sep='\t', index=False)

# %% [markdown]
# ## ROI metadata

# %%
data = []
for case, d in case_to_roi_to_data.items():
    for roi, dat in d.items():
        rids, sids, rid_to_patho = dat['rids'], dat['sids'], dat['rid_to_patho']
        for i, (rid, sid) in enumerate(zip(rids, sids)):
            annot = rid_to_patho[rid]
            data.append([case, roi, rid, sid, i + 1, annot])
region_3d_meta = pd.DataFrame(data=data, columns=['case', 'roi', 'region_id', 'section_id', 'region_index', 'pathology_annotation'])
region_3d_meta['pathology_annotation'] = [x.replace('IDC - partial', 'MI') for x in region_3d_meta['pathology_annotation']]
region_3d_meta
# Out:
#         case   roi                             region_id    section_id  \
# 0    HT704B1  roi1  b28d28d2-098a-41aa-8a99-24f8c8753897    HT704B1-U1
# 1    HT704B1  roi1  efac94bc-f48c-410e-a57d-3cfccc9f95f5    HT704B1-U2
# 2    HT704B1  roi1  e1967bc8-a7b8-4c08-94f1-20963ffb9e7d   HT704B1-U11
# 3    HT704B1  roi1  bdb3ea48-34e3-43e8-b8b6-042ab38be524   HT704B1-U12
# 4    HT704B1  roi1  25f59172-9dc6-4340-a21f-2a2b557176cf   HT704B1-U14
# ..       ...   ...                                   ...           ...
# 540  HT913Z1  roi1  f0b857f5-260b-4245-b625-664515bdbdf7  HT913Z1-U108
# 541  HT913Z1  roi1  707b6831-fa35-423f-b35c-86fbf4f2b14f  HT913Z1-U110
# 542  HT913Z1  roi1  a278652c-7add-4781-9926-959de4f531fd  HT913Z1-U111
# 543  HT913Z1  roi1  19b3be03-9e23-477e-a412-b9e36b31dac0  HT913Z1-U112
# 544  HT913Z1  roi1  05ba971a-105f-4dd5-b5b9-51fff0886986  HT913Z1-U115
#
#      region_index pathology_annotation
# 0               1                 DCIS
# 1               2                 DCIS
# 2               3                 DCIS
# 3               4                 DCIS
# 4               5                 DCIS
# ..            ...                  ...
# 540            65               Normal
# 541            66               Normal
# 542            67               Normal
# 543            68               Normal
# 544            69               Normal
#
# [545 rows x 6 columns]

# %%
region_3d_meta.to_csv(directory / 'region_3d_metadata.txt', sep='\t', index=False)

# %% [markdown]
# ## 2D DEG correlation

# %%
epi_genes = [
    'MGP',
    'FLRT3',
    'PLAT',
    'CD44',
    'KRT8',
    'ANPEP',
    'GDF15',
    'ALDH1A3',
    'FASN',
    'EPHA6',
]

tme_genes = [
    'SPP1',
    'MS4A6A',
    'MFAP5',
    'ASPN'
]

# %% [markdown]
# ## supporting counts

# %%
genes = """MGP
FLRT3
PLAT
CD44
KRT8
ANPEP
GDF15
ALDH1A3
FASN
EPHA6
SPP1
MS4A6A
MFAP5
ASPN
TCIM
TFF1
MKI67
HMGCS2
VEGFA
NTN4
SOX9
FASN
DUOXA1
UPK1A
SERPINA3
CPLX3
TCIM
SORL
FHL2
CP 
CAMK2N1
GFRA1
MYC
CEACAM20
GLUL
LGALS1
SLC40A1
mgp
plat/tpa
ki67
cd44""".split('\n')
genes
# Out:
# ['MGP',
#  'FLRT3',
#  'PLAT',
#  'CD44',
#  'KRT8',
#  'ANPEP',
#  'GDF15',
#  'ALDH1A3',
#  'FASN',
#  'EPHA6',
#  'SPP1',
#  'MS4A6A',
#  'MFAP5',
#  'ASPN',
#  'TCIM',
#  'TFF1',
#  'MKI67',
#  'HMGCS2',
#  'VEGFA',
#  'NTN4',
#  'SOX9',
#  'FASN',
#  'DUOXA1',
#  'UPK1A',
#  'SERPINA3',
#  'CPLX3',
#  'TCIM',
#  'SORL',
#  'FHL2',
#  'CP ',
#  'CAMK2N1',
#  'GFRA1',
#  'MYC',
#  'CEACAM20',
#  'GLUL',
#  'LGALS1',
#  'SLC40A1',
#  'mgp',
#  'plat/tpa',
#  'ki67',
#  'cd44']

# %%
pos_epi = ['MGP',
 'FLRT3',
 'PLAT',
 'TFF1',
 'HMGCS2',
 'VEGFA',
 'NTN4',
 'SOX9',
 'DUOXA1',
 'UPK1A',
 'CPLX3',
 'SORL',
 'FHL2',
 'CP ',
 'CAMK2N1',
 'GFRA1',
 'CEACAM20',
 'SLC40A1',
 'mgp',
 'plat/tpa'
]

neg_epi = [
 'CD44',
 'KRT8',
 'ANPEP',
 'GDF15',
 'ALDH1A3',
 'FASN',
 'EPHA6',
 'TCIM',
 'MKI67',
 'VEGFA',
 'FASN',
 'SERPINA3',
 'CPLX3',
 'TCIM',
 'CAMK2N1',
 'GFRA1',
 'MYC',
 'GLUL',
 'LGALS1',
 'SLC40A1',
 'ki67',
 'cd44']

pos_tme = [
    'MS4A6A',
]

neg_tme = [
    'SPP1',
    'MFAP5',
    'ASPN'
]

# %%
df = pd.read_csv(
    '/data/estorrs/mushroom/data/projects/submission_v1/analysis/region_characterization/results/counts_support.txt', sep='\t')
df['gene'] = [x.replace('region_', '').replace('tme_', '') for x in df['feature']]
df
# Out:
#        disease      dtype    type                               feature  \
# 0         brca  multiplex  region                      region_a-amylase
# 1         brca  multiplex  region                           region_bap1
# 2         brca  multiplex  region                           region_bca1
# 3         brca  multiplex  region                          region_cd11b
# 4         brca  multiplex  region                          region_cd163
# ...        ...        ...     ...                                   ...
# 153673    prad      vishd  region           region_celltypes_Macrophage
# 153674    prad      vishd  region                 region_celltypes_Mast
# 153675    prad      vishd  region             region_celltypes_Pericyte
# 153676    prad      vishd  region  region_celltypes_Smooth Muscle Cells
# 153677    prad      vishd  region               region_celltypes_T cell
#
#         sid_count  case_count  correlation  correlation_abs direction  \
# 0               1           1    -0.100809         0.100809  negative
# 1               1           1    -0.077325         0.077325  negative
# 2               6           2    -0.078976         0.078976  negative
# 3               6           1     0.074927         0.074927  positive
# 4               4           1    -0.022789         0.022789  negative
# ...           ...         ...          ...              ...       ...
# 153673          1           1     0.256306         0.256306  positive
# 153674          0           0     0.025979         0.025979  negative
# 153675          1           1     0.136376         0.136376  positive
# 153676          0           0    -0.000101         0.000101  negative
# 153677          0           0     0.031376         0.031376  negative
#
#                                  gene
# 0                           a-amylase
# 1                                bap1
# 2                                bca1
# 3                               cd11b
# 4                               cd163
# ...                               ...
# 153673           celltypes_Macrophage
# 153674                 celltypes_Mast
# 153675             celltypes_Pericyte
# 153676  celltypes_Smooth Muscle Cells
# 153677               celltypes_T cell
#
# [63306 rows x 10 columns]

# %%
df[df['gene']=='NTN4']
# Out:
#                                    disease     dtype    type      feature  \
# prad_cosmx_region_negative_NTN4       prad     cosmx  region  region_NTN4
# prad_cosmx6k_region_negative_NTN4     prad   cosmx6k  region  region_NTN4
# prad_cosmx_tme_negative_NTN4          prad     cosmx     tme     tme_NTN4
# prad_cosmx6k_tme_negative_NTN4        prad   cosmx6k     tme     tme_NTN4
# brca_xenium_region_negative_NTN4      brca    xenium  region  region_NTN4
# brca_xenium5k_region_negative_NTN4    brca  xenium5k  region  region_NTN4
# brca_xenium_tme_positive_NTN4         brca    xenium     tme     tme_NTN4
# brca_xenium5k_tme_negative_NTN4       brca  xenium5k     tme     tme_NTN4
# prad_xenium_region_positive_NTN4      prad    xenium  region  region_NTN4
# prad_xenium5k_region_positive_NTN4    prad  xenium5k  region  region_NTN4
# prad_xenium_tme_positive_NTN4         prad    xenium     tme     tme_NTN4
# prad_xenium5k_tme_positive_NTN4       prad  xenium5k     tme     tme_NTN4
# brca_vishd_region_negative_NTN4       brca     vishd  region  region_NTN4
# brca_vishd_tme_negative_NTN4          brca     vishd     tme     tme_NTN4
# prad_vishd_region_positive_NTN4       prad     vishd  region  region_NTN4
# prad_vishd_tme_positive_NTN4          prad     vishd     tme     tme_NTN4
#
#                                     sid_count  case_count  correlation  \
# prad_cosmx_region_negative_NTN4             0           0          NaN
# prad_cosmx6k_region_negative_NTN4           0           0     0.030317
# prad_cosmx_tme_negative_NTN4                0           0          NaN
# prad_cosmx6k_tme_negative_NTN4              0           0    -0.009673
# brca_xenium_region_negative_NTN4            7           2     0.143625
# brca_xenium5k_region_negative_NTN4          0           0          NaN
# brca_xenium_tme_positive_NTN4               8           3     0.243638
# brca_xenium5k_tme_negative_NTN4             0           0          NaN
# prad_xenium_region_positive_NTN4           37          19     0.453749
# prad_xenium5k_region_positive_NTN4          5           3     0.626290
# prad_xenium_tme_positive_NTN4              21          15     0.204694
# prad_xenium5k_tme_positive_NTN4             5           3     0.353792
# brca_vishd_region_negative_NTN4             0           0     0.079478
# brca_vishd_tme_negative_NTN4                1           1    -0.093510
# prad_vishd_region_positive_NTN4             2           1     0.476632
# prad_vishd_tme_positive_NTN4                2           1     0.331405
#
#                                     correlation_abs direction  gene
# prad_cosmx_region_negative_NTN4                 NaN  negative  NTN4
# prad_cosmx6k_region_negative_NTN4          0.030317  negative  NTN4
# prad_cosmx_tme_negative_NTN4                    NaN  negative  NTN4
# prad_cosmx6k_tme_negative_NTN4             0.009673  negative  NTN4
# brca_xenium_region_negative_NTN4           0.143625  negative  NTN4
# brca_xenium5k_region_negative_NTN4              NaN  negative  NTN4
# brca_xenium_tme_positive_NTN4              0.243638  positive  NTN4
# brca_xenium5k_tme_negative_NTN4                 NaN  negative  NTN4
# prad_xenium_region_positive_NTN4           0.453749  positive  NTN4
# prad_xenium5k_region_positive_NTN4         0.626290  positive  NTN4
# prad_xenium_tme_positive_NTN4              0.204694  positive  NTN4
# prad_xenium5k_tme_positive_NTN4            0.353792  positive  NTN4
# brca_vishd_region_negative_NTN4            0.079478  negative  NTN4
# brca_vishd_tme_negative_NTN4               0.093510  negative  NTN4
# prad_vishd_region_positive_NTN4            0.476632  positive  NTN4
# prad_vishd_tme_positive_NTN4               0.331405  positive  NTN4

# %%
def get_support_df(rtype, direction, genes):
    df.index = [f'{u}_{w}_{x}_{y}_{z}' for u, w, x, y, z in df[['disease', 'dtype', 'type', 'direction', 'gene']].values]
    dtypes = sorted(set(df['dtype']))
    diseases = sorted(set(df['disease']))
    
    data = []
    for gene in genes:
        xs = [gene]
        cols = ['gene']
        for disease in diseases:
            for dtype in dtypes:
                ident = f'{disease}_{dtype}_{rtype}_{direction}_{gene}'
                if ident in df.index:
                    row = df.loc[ident]
                    xs += [row['sid_count'], row['case_count'], row['correlation']]
                else:
                    xs += [np.nan, np.nan, np.nan]
                prefix = f'{disease}|{dtype}'
                cols += [f'{prefix}|{x}' for x in ['sid_count', 'case_count', 'correlation']]
        data.append(xs)
    
    support = pd.DataFrame(data=data, columns=cols)
    return support

# %%
rtype, direction = 'region', 'positive'
support = get_support_df(rtype, direction, pos_epi)

# %%
support.to_csv(f'/data/estorrs/mushroom/data/projects/submission_v1/analysis/region_characterization/results/key_genes_support_{direction}_{rtype}.txt',
               sep='\t', index=False)

# %%
rtype, direction = 'region', 'negative'
support = get_support_df(rtype, direction, neg_epi)

# %%
support.to_csv(f'/data/estorrs/mushroom/data/projects/submission_v1/analysis/region_characterization/results/key_genes_support_{direction}_{rtype}.txt',
               sep='\t', index=False)

# %%
rtype, direction = 'tme', 'positive'
support = get_support_df(rtype, direction, pos_tme)

# %%
support.to_csv(f'/data/estorrs/mushroom/data/projects/submission_v1/analysis/region_characterization/results/key_genes_support_{direction}_{rtype}.txt',
               sep='\t', index=False)

# %%
rtype, direction = 'tme', 'negative'
support = get_support_df(rtype, direction, neg_tme)

# %%
support.to_csv(f'/data/estorrs/mushroom/data/projects/submission_v1/analysis/region_characterization/results/key_genes_support_{direction}_{rtype}.txt',
               sep='\t', index=False)
