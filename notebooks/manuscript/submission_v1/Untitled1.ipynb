# %%
import json
import os
import sys
from copy import deepcopy
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import skimage
import tifffile
import yaml

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from mushroom.mushroom import Mushroom, DEFAULT_CONFIG
import mushroom.data.he as he
import mushroom.data.multiplex as multiplex
import mushroom.utils as utils
import mushroom.visualization.utils as vis_utils

# %%
mushroom = Mushroom.from_config(
#     '/data/estorrs/mushroom/data/projects/submission_v1/kidney/NMK12F-Fp1/mushroom'
    '/data/estorrs/mushroom/data/projects/submission_v1/kidney/NMK92F2-Fc1U1Bs2/mushroom'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 mushroom = Mushroom.from_config(
#       2 #     '/data/estorrs/mushroom/data/projects/submission_v1/kidney/NMK12F-Fp1/mushroom'
#       3     '/data/estorrs/mushroom/data/projects/submission_v1/kidney/NMK92F2-Fc1U1Bs2/mushroom'
#       4 )
#
# File /data/estorrs/mushroom/mushroom/mushroom.py:137, in Mushroom.from_config(input, accelerator)
#     134     else:
#     135         outputs = None
# --> 137     mushroom_config = yaml.safe_load(open(mushroom_config))
#     138 else:
#     139     mushroom_config = input
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/estorrs/mushroom/data/projects/submission_v1/kidney/NMK92F2-Fc1U1Bs2/mushroom/config.yaml'

# %%
mushroom.section_ids
# Out:
# [('NMK92F-Fp1-U1', 'xenium')]

# %%
mushroom.display_clusters('xenium', level=0)

# %%
mushroom.display_clusters('xenium', level=1, )

# %%
mushroom.display_clusters('xenium', level=2)
